# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))


from src.linear.factory import LinearModelFactory
from src.tree.factory import IdentificationTreeFactory
from src.ensembles.bagging.factory import BaggingFactory
from src.ensembles.boosting.factory import BoostingFactory
from src.neighborhood.factory import NearestNeighborFactory

# %% [markdown]
# ## **1) Dataset Preprocessing**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/Boston.csv')
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
scaled_df = StandardScaler().fit_transform(df)
x_df = scaled_df[:, :-1]
y_df = scaled_df[:, -1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((404, 14), (404,), (102, 14), (102,))

# %% [markdown]
# ## **Helper Function**

# %%
def evaluation(y_pred, y_test):
    return {
        "mse": ((y_test - y_pred) ** 2).mean(),
        "mae": abs(y_test - y_pred).mean(),
        "r2": 1 - ((y_test - y_pred) ** 2).sum() / ((y_test - y_test.mean()) ** 2).sum()
    }

# %% [markdown]
# ## **2) Machine Learning Model Experiments**

# %% [markdown]
# ### **2.1) Linear Models**

# %%
model = (
    LinearModelFactory.create("linear_regression")
    .compile(optimizer="sgd", loss='huber')
    .build()
)

model.fit(x_train, y_train, epochs=200)
y_pred = model.predict(x_test)

evaluation(y_pred.reshape(-1, ), y_test)
# Out:
# -------------------[EPOCH 1/200]---------------------
# Error: 1.0999237853649446
# -------------------[EPOCH 2/200]---------------------
# Error: 0.9438977860666258
# -------------------[EPOCH 3/200]---------------------
# Error: 0.838546480952417
# -------------------[EPOCH 4/200]---------------------
# Error: 0.7646788743484635
# -------------------[EPOCH 5/200]---------------------
# Error: 0.7099133369039247
# -------------------[EPOCH 6/200]---------------------
# Error: 0.6666181076289243
# -------------------[EPOCH 7/200]---------------------
# Error: 0.6300779738788075
# -------------------[EPOCH 8/200]---------------------
# Error: 0.5978156568958601
# -------------------[EPOCH 9/200]---------------------
# Error: 0.5686382145822559
# -------------------[EPOCH 10/200]---------------------
# Error: 0.5418462204595382
# -------------------[EPOCH 11/200]---------------------
# Error: 0.5170968793847938
# -------------------[EPOCH 12/200]---------------------
# Error: 0.49406840191378076
# -------------------[EPOCH 13/200]---------------------
# Error: 0.47253480974151146
# -------------------[EPOCH 14/200]---------------------
# Error: 0.45228890410269457
# -------------------[EPOCH 15/200]---------------------
# Error: 0.4332223262947855
# -------------------[EPOCH 16/200]---------------------
# Error: 0.4152447220146391
# -------------------[EPOCH 17/200]---------------------
# Error: 0.3982965262804528
# -------------------[EPOCH 18/200]---------------------
# Error: 0.3822999936912862
# -------------------[EPOCH 19/200]---------------------
# Error: 0.36719129536259215
# -------------------[EPOCH 20/200]---------------------
# Error: 0.3528949645041665
# -------------------[EPOCH 21/200]---------------------
# Error: 0.3393826494804424
# -------------------[EPOCH 22/200]---------------------
# Error: 0.32661977778721063
# -------------------[EPOCH 23/200]---------------------
# Error: 0.31454360208433585
# -------------------[EPOCH 24/200]---------------------
# Error: 0.30308477010230545
# -------------------[EPOCH 25/200]---------------------
# Error: 0.29217115105069746
# -------------------[EPOCH 26/200]---------------------
# Error: 0.2818530054215794
# -------------------[EPOCH 27/200]---------------------
# Error: 0.2721434246198998
# -------------------[EPOCH 28/200]---------------------
# Error: 0.2630066664898791
# -------------------[EPOCH 29/200]---------------------
# Error: 0.25443048735703083
# -------------------[EPOCH 30/200]---------------------
# Error: 0.24637889068705104
# -------------------[EPOCH 31/200]---------------------
# Error: 0.23884328911922237
# -------------------[EPOCH 32/200]---------------------
# Error: 0.2318295361340897
# -------------------[EPOCH 33/200]---------------------
# Error: 0.2253286351745629
# -------------------[EPOCH 34/200]---------------------
# Error: 0.2193015313535331
# -------------------[EPOCH 35/200]---------------------
# Error: 0.21370853396244957
# -------------------[EPOCH 36/200]---------------------
# Error: 0.2085099177924886
# -------------------[EPOCH 37/200]---------------------
# Error: 0.2036753309372312
# -------------------[EPOCH 38/200]---------------------
# Error: 0.19917570939450746
# -------------------[EPOCH 39/200]---------------------
# Error: 0.19501456002497394
# -------------------[EPOCH 40/200]---------------------
# Error: 0.1911676046605632
# -------------------[EPOCH 41/200]---------------------
# Error: 0.18759726214786587
# -------------------[EPOCH 42/200]---------------------
# Error: 0.18427249779409727
# -------------------[EPOCH 43/200]---------------------
# Error: 0.181167885311705
# -------------------[EPOCH 44/200]---------------------
# Error: 0.1782597496321658
# -------------------[EPOCH 45/200]---------------------
# Error: 0.17552732328039866
# -------------------[EPOCH 46/200]---------------------
# Error: 0.1729508375742091
# -------------------[EPOCH 47/200]---------------------
# Error: 0.1705117246995132
# -------------------[EPOCH 48/200]---------------------
# Error: 0.16820893016854432
# -------------------[EPOCH 49/200]---------------------
# Error: 0.16603293502491095
# -------------------[EPOCH 50/200]---------------------
# Error: 0.16397323494188293
# -------------------[EPOCH 51/200]---------------------
# Error: 0.16202232327840785
# -------------------[EPOCH 52/200]---------------------
# Error: 0.16017203823904702
# -------------------[EPOCH 53/200]---------------------
# Error: 0.1584159120549677
# -------------------[EPOCH 54/200]---------------------
# Error: 0.1567467230968631
# -------------------[EPOCH 55/200]---------------------
# Error: 0.15515892001784576
# -------------------[EPOCH 56/200]---------------------
# Error: 0.15364733764894772
# -------------------[EPOCH 57/200]---------------------
# Error: 0.1522077838353577
# -------------------[EPOCH 58/200]---------------------
# Error: 0.15083495437120592
# -------------------[EPOCH 59/200]---------------------
# Error: 0.149524075060556
# -------------------[EPOCH 60/200]---------------------
# Error: 0.14827096457909128
# -------------------[EPOCH 61/200]---------------------
# Error: 0.14707190400709286
# -------------------[EPOCH 62/200]---------------------
# Error: 0.1459235514267197
# -------------------[EPOCH 63/200]---------------------
# Error: 0.1448228818545177
# -------------------[EPOCH 64/200]---------------------
# Error: 0.143767142272987
# -------------------[EPOCH 65/200]---------------------
# Error: 0.14275381644498644
# -------------------[EPOCH 66/200]---------------------
# Error: 0.14178060946754317
# -------------------[EPOCH 67/200]---------------------
# Error: 0.14084540481615596
# -------------------[EPOCH 68/200]---------------------
# Error: 0.13994623550665403
# -------------------[EPOCH 69/200]---------------------
# Error: 0.13908128143653206
# -------------------[EPOCH 70/200]---------------------
# Error: 0.13824885418815794
# -------------------[EPOCH 71/200]---------------------
# Error: 0.13744738376051738
# -------------------[EPOCH 72/200]---------------------
# Error: 0.1366751960774525
# -------------------[EPOCH 73/200]---------------------
# Error: 0.13593083321529995
# -------------------[EPOCH 74/200]---------------------
# Error: 0.1352130519843837
# -------------------[EPOCH 75/200]---------------------
# Error: 0.13452229445171834
# -------------------[EPOCH 76/200]---------------------
# Error: 0.1338569302281602
# -------------------[EPOCH 77/200]---------------------
# Error: 0.1332147701459399
# -------------------[EPOCH 78/200]---------------------
# Error: 0.13259444280881272
# -------------------[EPOCH 79/200]---------------------
# Error: 0.13199484344873444
# -------------------[EPOCH 80/200]---------------------
# Error: 0.13141502760020676
# -------------------[EPOCH 81/200]---------------------
# Error: 0.130854154748054
# -------------------[EPOCH 82/200]---------------------
# Error: 0.13031145741746455
# -------------------[EPOCH 83/200]---------------------
# Error: 0.12978622352657856
# -------------------[EPOCH 84/200]---------------------
# Error: 0.12927778579158197
# -------------------[EPOCH 85/200]---------------------
# Error: 0.12878551496226737
# -------------------[EPOCH 86/200]---------------------
# Error: 0.12830881519424597
# -------------------[EPOCH 87/200]---------------------
# Error: 0.12784712065622061
# -------------------[EPOCH 88/200]---------------------
# Error: 0.12739989288528775
# -------------------[EPOCH 89/200]---------------------
# Error: 0.12696661862189718
# -------------------[EPOCH 90/200]---------------------
# Error: 0.1265461434254253
# -------------------[EPOCH 91/200]---------------------
# Error: 0.12613683346878266
# -------------------[EPOCH 92/200]---------------------
# Error: 0.1257428899518352
# -------------------[EPOCH 93/200]---------------------
# Error: 0.12536395328079825
# -------------------[EPOCH 94/200]---------------------
# Error: 0.1249994829287273
# -------------------[EPOCH 95/200]---------------------
# Error: 0.12464887021119615
# -------------------[EPOCH 96/200]---------------------
# Error: 0.12431149546294387
# -------------------[EPOCH 97/200]---------------------
# Error: 0.12398675502166503
# -------------------[EPOCH 98/200]---------------------
# Error: 0.12367407272397224
# -------------------[EPOCH 99/200]---------------------
# Error: 0.12337290376312979
# -------------------[EPOCH 100/200]---------------------
# Error: 0.12308273493396328
# -------------------[EPOCH 101/200]---------------------
# Error: 0.12280308327735732
# -------------------[EPOCH 102/200]---------------------
# Error: 0.12253349410774864
# -------------------[EPOCH 103/200]---------------------
# Error: 0.12227353889026463
# -------------------[EPOCH 104/200]---------------------
# Error: 0.1220228131782992
# -------------------[EPOCH 105/200]---------------------
# Error: 0.12178093469764142
# -------------------[EPOCH 106/200]---------------------
# Error: 0.12154754160391626
# -------------------[EPOCH 107/200]---------------------
# Error: 0.12132228154784412
# -------------------[EPOCH 108/200]---------------------
# Error: 0.12110472756833666
# -------------------[EPOCH 109/200]---------------------
# Error: 0.12089464410000512
# -------------------[EPOCH 110/200]---------------------
# Error: 0.12069174583483214
# -------------------[EPOCH 111/200]---------------------
# Error: 0.12049575842928707
# -------------------[EPOCH 112/200]---------------------
# Error: 0.12030641897393414
# -------------------[EPOCH 113/200]---------------------
# Error: 0.1201234758701127
# -------------------[EPOCH 114/200]---------------------
# Error: 0.11994727320533352
# -------------------[EPOCH 115/200]---------------------
# Error: 0.11977726741090743
# -------------------[EPOCH 116/200]---------------------
# Error: 0.11961316643292329
# -------------------[EPOCH 117/200]---------------------
# Error: 0.1194547221509583
# -------------------[EPOCH 118/200]---------------------
# Error: 0.11930170570075896
# -------------------[EPOCH 119/200]---------------------
# Error: 0.11915390255416161
# -------------------[EPOCH 120/200]---------------------
# Error: 0.1190111098292261
# -------------------[EPOCH 121/200]---------------------
# Error: 0.11887313470966498
# -------------------[EPOCH 122/200]---------------------
# Error: 0.11873979342742526
# -------------------[EPOCH 123/200]---------------------
# Error: 0.1186109105395742
# -------------------[EPOCH 124/200]---------------------
# Error: 0.11848631836591364
# -------------------[EPOCH 125/200]---------------------
# Error: 0.11836585652014714
# -------------------[EPOCH 126/200]---------------------
# Error: 0.11824937150022723
# -------------------[EPOCH 127/200]---------------------
# Error: 0.11813671631977186
# -------------------[EPOCH 128/200]---------------------
# Error: 0.11802775017057739
# -------------------[EPOCH 129/200]---------------------
# Error: 0.11792233811038459
# -------------------[EPOCH 130/200]---------------------
# Error: 0.11782035077217522
# -------------------[EPOCH 131/200]---------------------
# Error: 0.11772166409242522
# -------------------[EPOCH 132/200]---------------------
# Error: 0.11762615905637089
# -------------------[EPOCH 133/200]---------------------
# Error: 0.11753372145872949
# -------------------[EPOCH 134/200]---------------------
# Error: 0.11744424167857065
# -------------------[EPOCH 135/200]---------------------
# Error: 0.11735761446720096
# -------------------[EPOCH 136/200]---------------------
# Error: 0.11727373874806546
# -------------------[EPOCH 137/200]---------------------
# Error: 0.11719251742777631
# -------------------[EPOCH 138/200]---------------------
# Error: 0.1171138572174629
# -------------------[EPOCH 139/200]---------------------
# Error: 0.1170376684637232
# -------------------[EPOCH 140/200]---------------------
# Error: 0.116963864988515
# -------------------[EPOCH 141/200]---------------------
# Error: 0.11689236393739233
# -------------------[EPOCH 142/200]---------------------
# Error: 0.11682308563553585
# -------------------[EPOCH 143/200]---------------------
# Error: 0.1167559534510804
# -------------------[EPOCH 144/200]---------------------
# Error: 0.11669089366528076
# -------------------[EPOCH 145/200]---------------------
# Error: 0.11662783534909296
# -------------------[EPOCH 146/200]---------------------
# Error: 0.11656671024578265
# -------------------[EPOCH 147/200]---------------------
# Error: 0.11650745265920497
# -------------------[EPOCH 148/200]---------------------
# Error: 0.11644999934742122
# -------------------[EPOCH 149/200]---------------------
# Error: 0.11639428942134937
# -------------------[EPOCH 150/200]---------------------
# Error: 0.11634023609946981
# -------------------[EPOCH 151/200]---------------------
# Error: 0.11628785866280067
# -------------------[EPOCH 152/200]---------------------
# Error: 0.11623712295626712
# -------------------[EPOCH 153/200]---------------------
# Error: 0.11618797929114145
# -------------------[EPOCH 154/200]---------------------
# Error: 0.1161403732357577
# -------------------[EPOCH 155/200]---------------------
# Error: 0.11609425203354401
# -------------------[EPOCH 156/200]---------------------
# Error: 0.11604956469249145
# -------------------[EPOCH 157/200]---------------------
# Error: 0.11600626199796964
# -------------------[EPOCH 158/200]---------------------
# Error: 0.11596429735219858
# -------------------[EPOCH 159/200]---------------------
# Error: 0.1159236245896748
# -------------------[EPOCH 160/200]---------------------
# Error: 0.11588419961582322
# -------------------[EPOCH 161/200]---------------------
# Error: 0.11584597994691005
# -------------------[EPOCH 162/200]---------------------
# Error: 0.11580892464827526
# -------------------[EPOCH 163/200]---------------------
# Error: 0.11577299428103828
# -------------------[EPOCH 164/200]---------------------
# Error: 0.11573815084878995
# -------------------[EPOCH 165/200]---------------------
# Error: 0.11570435774501796
# -------------------[EPOCH 166/200]---------------------
# Error: 0.1156715797016617
# -------------------[EPOCH 167/200]---------------------
# Error: 0.11563978273900885
# -------------------[EPOCH 168/200]---------------------
# Error: 0.11560893411705551
# -------------------[EPOCH 169/200]---------------------
# Error: 0.11557900228839746
# -------------------[EPOCH 170/200]---------------------
# Error: 0.11554995685267984
# -------------------[EPOCH 171/200]---------------------
# Error: 0.11552176851262365
# -------------------[EPOCH 172/200]---------------------
# Error: 0.11549440903161733
# -------------------[EPOCH 173/200]---------------------
# Error: 0.1154678511928602
# -------------------[EPOCH 174/200]---------------------
# Error: 0.11544206876003481
# -------------------[EPOCH 175/200]---------------------
# Error: 0.11541703643947378
# -------------------[EPOCH 176/200]---------------------
# Error: 0.11539272984378726
# -------------------[EPOCH 177/200]---------------------
# Error: 0.11536912545691135
# -------------------[EPOCH 178/200]---------------------
# Error: 0.11534620060053417
# -------------------[EPOCH 179/200]---------------------
# Error: 0.11532393340185604
# -------------------[EPOCH 180/200]---------------------
# Error: 0.115302302762641
# -------------------[EPOCH 181/200]---------------------
# Error: 0.11528128832950967
# -------------------[EPOCH 182/200]---------------------
# Error: 0.11526087046543355
# -------------------[EPOCH 183/200]---------------------
# Error: 0.11524103022237936
# -------------------[EPOCH 184/200]---------------------
# Error: 0.11522174931506567
# -------------------[EPOCH 185/200]---------------------
# Error: 0.11520301009578093
# -------------------[EPOCH 186/200]---------------------
# Error: 0.11518479553022679
# -------------------[EPOCH 187/200]---------------------
# Error: 0.11516708917434082
# -------------------[EPOCH 188/200]---------------------
# Error: 0.11514987515205843
# -------------------[EPOCH 189/200]---------------------
# Error: 0.1151331381339775
# -------------------[EPOCH 190/200]---------------------
# Error: 0.1151168633168855
# -------------------[EPOCH 191/200]---------------------
# Error: 0.11510103640411512
# -------------------[EPOCH 192/200]---------------------
# Error: 0.11508564358668812
# -------------------[EPOCH 193/200]---------------------
# Error: 0.11507067152522299
# -------------------[EPOCH 194/200]---------------------
# Error: 0.11505610733256344
# -------------------[EPOCH 195/200]---------------------
# Error: 0.11504193855710568
# -------------------[EPOCH 196/200]---------------------
# Error: 0.11502815316678812
# -------------------[EPOCH 197/200]---------------------
# Error: 0.11501473953372092
# -------------------[EPOCH 198/200]---------------------
# Error: 0.11500168641942256
# -------------------[EPOCH 199/200]---------------------
# Error: 0.11498898296064262
# -------------------[EPOCH 200/200]---------------------
# Error: 0.11497661865574064
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 9
#       1 model = (
#       2     LinearModelFactory.create("linear_regression")
#       3     .compile(optimizer="sgd", loss='huber')
#       4     .build()
#       5     .fit(x_train, y_train, epochs=200)
#       6 )
#       8 # model.fit(x_train, y_train, epochs=200)
# ----> 9 y_pred = model.predict(x_test)
#      11 evaluation(y_pred.reshape(-1, ), y_test)
#
# AttributeError: 'NoneType' object has no attribute 'predict'

# %%
model = (
    BoostingFactory.create("regressor")
    .compile(n_estimators=10, learning_rate=0.1, max_depth=5, impurity_type="squared_loss")
    .build()
)

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

evaluation(y_pred, y_test)
# Out:
# -------------------[Iteration 0/10]---------------------
# Error : 0.6501683782149524
# -------------------[Iteration 1/10]---------------------
# Error : 0.4392855595321931
# -------------------[Iteration 2/10]---------------------
# Error : 0.3040970445759601
# -------------------[Iteration 3/10]---------------------
# Error : 0.21286330635516665
# -------------------[Iteration 4/10]---------------------
# Error : 0.15121356327752422
# -------------------[Iteration 5/10]---------------------
# Error : 0.10922861496272179
# -------------------[Iteration 6/10]---------------------
# Error : 0.08176271374149606
# -------------------[Iteration 7/10]---------------------
# Error : 0.06265158100353259
# -------------------[Iteration 8/10]---------------------
# Error : 0.04850211870978394
# -------------------[Iteration 9/10]---------------------
# Error : 0.03953270665115571
# {'mse': np.float64(0.13347036966310763),
#  'mae': np.float64(0.2608726868774021),
#  'r2': np.float64(0.8766436463741313)}

# %%
model = (
    NearestNeighborFactory.create("regressor")
    .compile(k=10, metrics="manhattan")
    .build()
)

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

evaluation(y_pred, y_test)
# Out:
# {'mse': np.float64(0.21297396557972456),
#  'mae': np.float64(0.30283494602508226),
#  'r2': np.float64(0.8031646134084409)}

# %%
model = (
    IdentificationTreeFactory.create("regressor")
    .compile(max_depth=100, impurity_type="mse")
    .build()
)

# bagged_model = (
#     BaggingFactory.create("regressor")
#     .compile(n_estimators=10, estimator=model)
#     .build()

# )

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

evaluation(y_pred, y_test)
# Out:
# {'mse': np.float64(0.1985507788792941),
#  'mae': np.float64(0.32629902573718395),
#  'r2': np.float64(0.8164948508500625)}
