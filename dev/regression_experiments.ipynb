# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# from src.linear.models.svm import SVM
# from src.linear.models.linear import LinearRegression
from src.tree.factory import IdentificationTreeFactory
from src.ensembles.bagging.factory import BaggingFactory
from src.neighborhood.factory import NearestNeighborFactory
# from src.ensembles.boosting.gradient import GradientBoostedRegressionTree

from src.linear.factory import LinearModelFactory

# %% [markdown]
# ## **1) Dataset Preprocessing**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/Boston.csv')
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
scaled_df = StandardScaler().fit_transform(df)
x_df = scaled_df[:, :-1]
y_df = scaled_df[:, -1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((404, 14), (404,), (102, 14), (102,))

# %% [markdown]
# ## **Helper Function**

# %%
def evaluation(y_pred, y_test):
    return {
        "mse": ((y_test - y_pred) ** 2).mean(),
        "mae": abs(y_test - y_pred).mean(),
        "r2": 1 - ((y_test - y_pred) ** 2).sum() / ((y_test - y_test.mean()) ** 2).sum()
    }

# %% [markdown]
# ## **2) Machine Learning Model Experiments**

# %% [markdown]
# ### **2.1) Linear Models**

# %%
model = (
    LinearModelFactory.create("linear_regression")
    .compile(optimizer="sgd", loss='huber')
    .build()
)

model.fit(x_train, y_train, epochs=200)
y_pred = model.predict(x_test)

evaluation(y_pred.reshape(-1, ), y_test)
# Out:
# -------------------[EPOCH 1/200]---------------------
# Error: 1.6372549822640121
# -------------------[EPOCH 2/200]---------------------
# Error: 1.3872041783182048
# -------------------[EPOCH 3/200]---------------------
# Error: 1.2068609811086208
# -------------------[EPOCH 4/200]---------------------
# Error: 1.0762823488147808
# -------------------[EPOCH 5/200]---------------------
# Error: 0.9785910445704042
# -------------------[EPOCH 6/200]---------------------
# Error: 0.9035195428625158
# -------------------[EPOCH 7/200]---------------------
# Error: 0.8431678062095844
# -------------------[EPOCH 8/200]---------------------
# Error: 0.7917592942376314
# -------------------[EPOCH 9/200]---------------------
# Error: 0.7461014964289681
# -------------------[EPOCH 10/200]---------------------
# Error: 0.7042795817308061
# -------------------[EPOCH 11/200]---------------------
# Error: 0.6653104671440715
# -------------------[EPOCH 12/200]---------------------
# Error: 0.6285678028402334
# -------------------[EPOCH 13/200]---------------------
# Error: 0.5936685602621397
# -------------------[EPOCH 14/200]---------------------
# Error: 0.5604011494281664
# -------------------[EPOCH 15/200]---------------------
# Error: 0.5286475285771798
# -------------------[EPOCH 16/200]---------------------
# Error: 0.49837087323396706
# -------------------[EPOCH 17/200]---------------------
# Error: 0.4695709001468083
# -------------------[EPOCH 18/200]---------------------
# Error: 0.44223194041281344
# -------------------[EPOCH 19/200]---------------------
# Error: 0.41648935677585514
# -------------------[EPOCH 20/200]---------------------
# Error: 0.3923749873715904
# -------------------[EPOCH 21/200]---------------------
# Error: 0.3698974197827227
# -------------------[EPOCH 22/200]---------------------
# Error: 0.34899328478579633
# -------------------[EPOCH 23/200]---------------------
# Error: 0.3295732543273971
# -------------------[EPOCH 24/200]---------------------
# Error: 0.3116099222414629
# -------------------[EPOCH 25/200]---------------------
# Error: 0.29503396219155853
# -------------------[EPOCH 26/200]---------------------
# Error: 0.2797395340563954
# -------------------[EPOCH 27/200]---------------------
# Error: 0.26569083095822754
# -------------------[EPOCH 28/200]---------------------
# Error: 0.252840255962118
# -------------------[EPOCH 29/200]---------------------
# Error: 0.24111504631610767
# -------------------[EPOCH 30/200]---------------------
# Error: 0.23041496603971015
# -------------------[EPOCH 31/200]---------------------
# Error: 0.22063814146076988
# -------------------[EPOCH 32/200]---------------------
# Error: 0.2117316114768067
# -------------------[EPOCH 33/200]---------------------
# Error: 0.20366894546299313
# -------------------[EPOCH 34/200]---------------------
# Error: 0.1963604665130779
# -------------------[EPOCH 35/200]---------------------
# Error: 0.1897155794603378
# -------------------[EPOCH 36/200]---------------------
# Error: 0.18366153150281314
# -------------------[EPOCH 37/200]---------------------
# Error: 0.17813234456968036
# -------------------[EPOCH 38/200]---------------------
# Error: 0.1730724622013296
# -------------------[EPOCH 39/200]---------------------
# Error: 0.1684338969943792
# -------------------[EPOCH 40/200]---------------------
# Error: 0.16417507573956755
# -------------------[EPOCH 41/200]---------------------
# Error: 0.1602694934959991
# -------------------[EPOCH 42/200]---------------------
# Error: 0.1567036619437626
# -------------------[EPOCH 43/200]---------------------
# Error: 0.15345590616745106
# -------------------[EPOCH 44/200]---------------------
# Error: 0.15049572923885643
# -------------------[EPOCH 45/200]---------------------
# Error: 0.14779028018298535
# -------------------[EPOCH 46/200]---------------------
# Error: 0.14531916862414485
# -------------------[EPOCH 47/200]---------------------
# Error: 0.14305928731574946
# -------------------[EPOCH 48/200]---------------------
# Error: 0.14098963395768396
# -------------------[EPOCH 49/200]---------------------
# Error: 0.13909135383417667
# -------------------[EPOCH 50/200]---------------------
# Error: 0.13734761580004404
# -------------------[EPOCH 51/200]---------------------
# Error: 0.13574343319092483
# -------------------[EPOCH 52/200]---------------------
# Error: 0.1342656848237057
# -------------------[EPOCH 53/200]---------------------
# Error: 0.13290241042861392
# -------------------[EPOCH 54/200]---------------------
# Error: 0.1316435509830677
# -------------------[EPOCH 55/200]---------------------
# Error: 0.1304805459359101
# -------------------[EPOCH 56/200]---------------------
# Error: 0.12940476657494981
# -------------------[EPOCH 57/200]---------------------
# Error: 0.12840858671114355
# -------------------[EPOCH 58/200]---------------------
# Error: 0.12748498500225708
# -------------------[EPOCH 59/200]---------------------
# Error: 0.12662761399882194
# -------------------[EPOCH 60/200]---------------------
# Error: 0.12583076201944265
# -------------------[EPOCH 61/200]---------------------
# Error: 0.1250893029006192
# -------------------[EPOCH 62/200]---------------------
# Error: 0.12439870572741575
# -------------------[EPOCH 63/200]---------------------
# Error: 0.12375350594269095
# -------------------[EPOCH 64/200]---------------------
# Error: 0.12314992333091294
# -------------------[EPOCH 65/200]---------------------
# Error: 0.12258463657771018
# -------------------[EPOCH 66/200]---------------------
# Error: 0.12205485122564164
# -------------------[EPOCH 67/200]---------------------
# Error: 0.12155796224627208
# -------------------[EPOCH 68/200]---------------------
# Error: 0.1210915703003396
# -------------------[EPOCH 69/200]---------------------
# Error: 0.12065347481630073
# -------------------[EPOCH 70/200]---------------------
# Error: 0.12024166091349352
# -------------------[EPOCH 71/200]---------------------
# Error: 0.11985428433763441
# -------------------[EPOCH 72/200]---------------------
# Error: 0.11948965634452745
# -------------------[EPOCH 73/200]---------------------
# Error: 0.11914622937754456
# -------------------[EPOCH 74/200]---------------------
# Error: 0.11882258386066939
# -------------------[EPOCH 75/200]---------------------
# Error: 0.1185174161830163
# -------------------[EPOCH 76/200]---------------------
# Error: 0.11822952784003216
# -------------------[EPOCH 77/200]---------------------
# Error: 0.11795782710589248
# -------------------[EPOCH 78/200]---------------------
# Error: 0.1177014273032634
# -------------------[EPOCH 79/200]---------------------
# Error: 0.11745934936348318
# -------------------[EPOCH 80/200]---------------------
# Error: 0.11723068511546361
# -------------------[EPOCH 81/200]---------------------
# Error: 0.11701461110626236
# -------------------[EPOCH 82/200]---------------------
# Error: 0.11681037305223164
# -------------------[EPOCH 83/200]---------------------
# Error: 0.11661727060310334
# -------------------[EPOCH 84/200]---------------------
# Error: 0.1164345649270618
# -------------------[EPOCH 85/200]---------------------
# Error: 0.1162619316735916
# -------------------[EPOCH 86/200]---------------------
# Error: 0.11609876722830435
# -------------------[EPOCH 87/200]---------------------
# Error: 0.11594452197384174
# -------------------[EPOCH 88/200]---------------------
# Error: 0.11579869324427897
# -------------------[EPOCH 89/200]---------------------
# Error: 0.115660809249212
# -------------------[EPOCH 90/200]---------------------
# Error: 0.11553043303415611
# -------------------[EPOCH 91/200]---------------------
# Error: 0.11540715861367236
# -------------------[EPOCH 92/200]---------------------
# Error: 0.11529060783570688
# -------------------[EPOCH 93/200]---------------------
# Error: 0.11518042774421104
# -------------------[EPOCH 94/200]---------------------
# Error: 0.11507628830678393
# -------------------[EPOCH 95/200]---------------------
# Error: 0.11497788042605193
# -------------------[EPOCH 96/200]---------------------
# Error: 0.11488491418149357
# -------------------[EPOCH 97/200]---------------------
# Error: 0.11479711760557297
# -------------------[EPOCH 98/200]---------------------
# Error: 0.11471423121038206
# -------------------[EPOCH 99/200]---------------------
# Error: 0.11463601164990428
# -------------------[EPOCH 100/200]---------------------
# Error: 0.11456223663175774
# -------------------[EPOCH 101/200]---------------------
# Error: 0.11449269164434459
# -------------------[EPOCH 102/200]---------------------
# Error: 0.11442717407411178
# -------------------[EPOCH 103/200]---------------------
# Error: 0.11436549235716964
# -------------------[EPOCH 104/200]---------------------
# Error: 0.11430746518750995
# -------------------[EPOCH 105/200]---------------------
# Error: 0.11425292080917422
# -------------------[EPOCH 106/200]---------------------
# Error: 0.1142016963765454
# -------------------[EPOCH 107/200]---------------------
# Error: 0.11415363737223354
# -------------------[EPOCH 108/200]---------------------
# Error: 0.11410859707495521
# -------------------[EPOCH 109/200]---------------------
# Error: 0.11406643607154343
# -------------------[EPOCH 110/200]---------------------
# Error: 0.11402702180830691
# -------------------[EPOCH 111/200]---------------------
# Error: 0.11399022817771695
# -------------------[EPOCH 112/200]---------------------
# Error: 0.11395593513694767
# -------------------[EPOCH 113/200]---------------------
# Error: 0.11392402835522797
# -------------------[EPOCH 114/200]---------------------
# Error: 0.11389439888732097
# -------------------[EPOCH 115/200]---------------------
# Error: 0.11386694272684027
# -------------------[EPOCH 116/200]---------------------
# Error: 0.11384155979874044
# -------------------[EPOCH 117/200]---------------------
# Error: 0.11381815574550946
# -------------------[EPOCH 118/200]---------------------
# Error: 0.11379664022649127
# -------------------[EPOCH 119/200]---------------------
# Error: 0.11377692702331789
# -------------------[EPOCH 120/200]---------------------
# Error: 0.11375893380533553
# -------------------[EPOCH 121/200]---------------------
# Error: 0.11374258191976595
# -------------------[EPOCH 122/200]---------------------
# Error: 0.11372779620004247
# -------------------[EPOCH 123/200]---------------------
# Error: 0.11371450478858876
# -------------------[EPOCH 124/200]---------------------
# Error: 0.11370263897176743
# -------------------[EPOCH 125/200]---------------------
# Error: 0.11369213306468587
# -------------------[EPOCH 126/200]---------------------
# Error: 0.11368292557451513
# -------------------[EPOCH 127/200]---------------------
# Error: 0.11367495682199841
# -------------------[EPOCH 128/200]---------------------
# Error: 0.11366816937627341
# -------------------[EPOCH 129/200]---------------------
# Error: 0.11366250816106768
# -------------------[EPOCH 130/200]---------------------
# Error: 0.11365792170092587
# -------------------[EPOCH 131/200]---------------------
# Error: 0.11365436046155054
# -------------------[EPOCH 132/200]---------------------
# Error: 0.1136517756482912
# -------------------[EPOCH 133/200]---------------------
# Error: 0.11365011916329248
# -------------------[EPOCH 134/200]---------------------
# Error: 0.11364932569914424
# -------------------[EPOCH 135/200]---------------------
# Error: 0.11364934216421207
# -------------------[EPOCH 136/200]---------------------
# Error: 0.11365012821454211
# -------------------[EPOCH 137/200]---------------------
# Error: 0.11365164537578362
# -------------------[EPOCH 138/200]---------------------
# Error: 0.11365385689430897
# -------------------[EPOCH 139/200]---------------------
# Error: 0.1136567276278272
# -------------------[EPOCH 140/200]---------------------
# Error: 0.11366022395740066
# -------------------[EPOCH 141/200]---------------------
# Error: 0.11366431371176942
# -------------------[EPOCH 142/200]---------------------
# Error: 0.11366896609936582
# -------------------[EPOCH 143/200]---------------------
# Error: 0.11367415164564494
# -------------------[EPOCH 144/200]---------------------
# Error: 0.11367984213445961
# -------------------[EPOCH 145/200]---------------------
# Error: 0.11368601055277557
# -------------------[EPOCH 146/200]---------------------
# Error: 0.11369263103830284
# -------------------[EPOCH 147/200]---------------------
# Error: 0.11369967882976276
# -------------------[EPOCH 148/200]---------------------
# Error: 0.11370713021958813
# -------------------[EPOCH 149/200]---------------------
# Error: 0.11371496250889082
# -------------------[EPOCH 150/200]---------------------
# Error: 0.11372315396456499
# -------------------[EPOCH 151/200]---------------------
# Error: 0.11373168377839625
# -------------------[EPOCH 152/200]---------------------
# Error: 0.11374053202807216
# -------------------[EPOCH 153/200]---------------------
# Error: 0.11374967963998542
# -------------------[EPOCH 154/200]---------------------
# Error: 0.11375910728004922
# -------------------[EPOCH 155/200]---------------------
# Error: 0.11376879358953321
# -------------------[EPOCH 156/200]---------------------
# Error: 0.11377872411649827
# -------------------[EPOCH 157/200]---------------------
# Error: 0.11378888309417783
# -------------------[EPOCH 158/200]---------------------
# Error: 0.11379925543966354
# -------------------[EPOCH 159/200]---------------------
# Error: 0.11380982671763015
# -------------------[EPOCH 160/200]---------------------
# Error: 0.11382058311000334
# -------------------[EPOCH 161/200]---------------------
# Error: 0.11383151138909663
# -------------------[EPOCH 162/200]---------------------
# Error: 0.1138425988929621
# -------------------[EPOCH 163/200]---------------------
# Error: 0.11385383350230316
# -------------------[EPOCH 164/200]---------------------
# Error: 0.11386520361861323
# -------------------[EPOCH 165/200]---------------------
# Error: 0.1138766981433441
# -------------------[EPOCH 166/200]---------------------
# Error: 0.11388830645799372
# -------------------[EPOCH 167/200]---------------------
# Error: 0.11390001840503838
# -------------------[EPOCH 168/200]---------------------
# Error: 0.11391182426965224
# -------------------[EPOCH 169/200]---------------------
# Error: 0.11392371476217811
# -------------------[EPOCH 170/200]---------------------
# Error: 0.1139356810013032
# -------------------[EPOCH 171/200]---------------------
# Error: 0.11394771449791558
# -------------------[EPOCH 172/200]---------------------
# Error: 0.11395980713960645
# -------------------[EPOCH 173/200]---------------------
# Error: 0.11397195117579037
# -------------------[EPOCH 174/200]---------------------
# Error: 0.11398413920341807
# -------------------[EPOCH 175/200]---------------------
# Error: 0.11399636415325606
# -------------------[EPOCH 176/200]---------------------
# Error: 0.1140086192767083
# -------------------[EPOCH 177/200]---------------------
# Error: 0.11402089813315833
# -------------------[EPOCH 178/200]---------------------
# Error: 0.11403319457780935
# -------------------[EPOCH 179/200]---------------------
# Error: 0.11404550358813997
# -------------------[EPOCH 180/200]---------------------
# Error: 0.1140578208350616
# -------------------[EPOCH 181/200]---------------------
# Error: 0.11407014107070558
# -------------------[EPOCH 182/200]---------------------
# Error: 0.11408245883599304
# -------------------[EPOCH 183/200]---------------------
# Error: 0.11409476904065836
# -------------------[EPOCH 184/200]---------------------
# Error: 0.11410706689540086
# -------------------[EPOCH 185/200]---------------------
# Error: 0.11411934787322171
# -------------------[EPOCH 186/200]---------------------
# Error: 0.11413160768549847
# -------------------[EPOCH 187/200]---------------------
# Error: 0.11414384226559104
# -------------------[EPOCH 188/200]---------------------
# Error: 0.11415604775638954
# -------------------[EPOCH 189/200]---------------------
# Error: 0.11416822050000357
# -------------------[EPOCH 190/200]---------------------
# Error: 0.11418035702868935
# -------------------[EPOCH 191/200]---------------------
# Error: 0.11419245405655744
# -------------------[EPOCH 192/200]---------------------
# Error: 0.1142045084718265
# -------------------[EPOCH 193/200]---------------------
# Error: 0.1142165173294995
# -------------------[EPOCH 194/200]---------------------
# Error: 0.11422847784438939
# -------------------[EPOCH 195/200]---------------------
# Error: 0.11424038738446066
# -------------------[EPOCH 196/200]---------------------
# Error: 0.11425224346445409
# -------------------[EPOCH 197/200]---------------------
# Error: 0.1142640437397802
# -------------------[EPOCH 198/200]---------------------
# Error: 0.11427578600066438
# -------------------[EPOCH 199/200]---------------------
# Error: 0.11428746816653057
# -------------------[EPOCH 200/200]---------------------
# Error: 0.11429908828061668
# {'mse': np.float64(0.35622612701582995),
#  'mae': np.float64(0.3704610222906671),
#  'r2': np.float64(0.5810787282236443)}

# %%
model = GradientBoostedRegressionTree()
model.compile(n_estimators=10, learning_rate=0.1, max_depth=3, impurity_type="huber")

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

evaluation(y_pred, y_test)
# Out:
# -------------------[Iteration 0/10]---------------------
# Error : 0.3844905493645985
# -------------------[Iteration 1/10]---------------------
# Error : 0.35076804382331167
# -------------------[Iteration 2/10]---------------------
# Error : 0.3202994307140073
# -------------------[Iteration 3/10]---------------------
# Error : 0.29244992452779683
# -------------------[Iteration 4/10]---------------------
# Error : 0.2672993149312308
# -------------------[Iteration 5/10]---------------------
# Error : 0.2451150494289032
# -------------------[Iteration 6/10]---------------------
# Error : 0.22536536622580386
# -------------------[Iteration 7/10]---------------------
# Error : 0.20778695485764595
# -------------------[Iteration 8/10]---------------------
# Error : 0.19066823600004298
# -------------------[Iteration 9/10]---------------------
# Error : 0.17537899847913607
# {'mse': np.float64(0.24711754974615802),
#  'mae': np.float64(0.3367737861228029),
#  'r2': np.float64(0.6010884853480787)}

# %%
model = (
    NearestNeighborFactory.create("regressor")
    .compile(k=4, metrics="manhattan")
    .build()
)

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

evaluation(y_pred, y_test)
# Out:
# {'mse': np.float64(0.1294042867362617),
#  'mae': np.float64(0.2723604523198698),
#  'r2': np.float64(0.800622099435147)}

# %%
model = (
    IdentificationTreeFactory.create("regressor")
    .compile(max_depth=100, impurity_type="mse")
    .build()
)

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

evaluation(y_pred, y_test)
# Out:
# {'mse': np.float64(0.2393147282115792),
#  'mae': np.float64(0.3182962700372857),
#  'r2': np.float64(0.6924019977107047)}
