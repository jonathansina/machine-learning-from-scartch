# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.linear.models.svm import SVM
from src.linear.models.linear import LinearRegression
from src.tree.factory import IdentificationTreeFactory
from src.ensembles.bagging.factory import BaggingFactory
from src.neighborhood.factory import NearestNeighborFactory
from src.ensembles.boosting.gradient import GradientBoostedRegressionTree

# %% [markdown]
# ## **1) Dataset Preprocessing**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../data/Boston.csv')
df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio   black  lstat  medv
# 0    296     15.3  396.90   4.98  24.0
# 1    242     17.8  396.90   9.14  21.6
# 2    242     17.8  392.83   4.03  34.7
# 3    222     18.7  394.63   2.94  33.4
# 4    222     18.7  396.90   5.33  36.2
# ..   ...      ...     ...    ...   ...
# 501  273     21.0  391.99   9.67  22.4
# 502  273     21.0  396.90   9.08  20.6
# 503  273     21.0  396.90   5.64  23.9
# 504  273     21.0  393.45   6.48  22.0
# 505  273     21.0  396.90   7.88  11.9
#
# [506 rows x 15 columns]

# %%
scaled_df = StandardScaler().fit_transform(df)
x_df = scaled_df[:, :-1]
y_df = scaled_df[:, -1]

# %%
x_train, x_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((404, 14), (404,), (102, 14), (102,))

# %% [markdown]
# ## **Helper Function**

# %%
def evaluation(y_pred, y_test):
    return {
        "mse": ((y_test - y_pred) ** 2).mean(),
        "mae": abs(y_test - y_pred).mean(),
        "r2": 1 - ((y_test - y_pred) ** 2).sum() / ((y_test - y_test.mean()) ** 2).sum()
    }

# %% [markdown]
# ## **2) Machine Learning Model Experiments**

# %% [markdown]
# ### **2.1) Linear Models**

# %%
model = LinearRegression()
model.compile(optimizer="sgd", loss='huber')

model.fit(x_train, y_train, epochs=200)
y_pred = model.predict(x_test)

evaluation(y_pred.reshape(-1, ), y_test)
# Out:
# -------------------[EPOCH 1/200]---------------------
# Error: 0.8716851750302331
# -------------------[EPOCH 2/200]---------------------
# Error: 0.8255820978147721
# -------------------[EPOCH 3/200]---------------------
# Error: 0.7838965049748893
# -------------------[EPOCH 4/200]---------------------
# Error: 0.7460142654950316
# -------------------[EPOCH 5/200]---------------------
# Error: 0.7112815399632976
# -------------------[EPOCH 6/200]---------------------
# Error: 0.6792441603916831
# -------------------[EPOCH 7/200]---------------------
# Error: 0.6495552647104489
# -------------------[EPOCH 8/200]---------------------
# Error: 0.621979676134949
# -------------------[EPOCH 9/200]---------------------
# Error: 0.5963232142932788
# -------------------[EPOCH 10/200]---------------------
# Error: 0.5723945195155498
# -------------------[EPOCH 11/200]---------------------
# Error: 0.5500804366238053
# -------------------[EPOCH 12/200]---------------------
# Error: 0.5292249988827108
# -------------------[EPOCH 13/200]---------------------
# Error: 0.5096737745201999
# -------------------[EPOCH 14/200]---------------------
# Error: 0.49125343437425484
# -------------------[EPOCH 15/200]---------------------
# Error: 0.4738614562024254
# -------------------[EPOCH 16/200]---------------------
# Error: 0.45740343701955216
# -------------------[EPOCH 17/200]---------------------
# Error: 0.4417753664591857
# -------------------[EPOCH 18/200]---------------------
# Error: 0.42687569470279324
# -------------------[EPOCH 19/200]---------------------
# Error: 0.41261766342125916
# -------------------[EPOCH 20/200]---------------------
# Error: 0.39892356707222476
# -------------------[EPOCH 21/200]---------------------
# Error: 0.3857214461127496
# -------------------[EPOCH 22/200]---------------------
# Error: 0.3729560283459263
# -------------------[EPOCH 23/200]---------------------
# Error: 0.36058221569917
# -------------------[EPOCH 24/200]---------------------
# Error: 0.34856712139258494
# -------------------[EPOCH 25/200]---------------------
# Error: 0.3368934793418546
# -------------------[EPOCH 26/200]---------------------
# Error: 0.3255436342369715
# -------------------[EPOCH 27/200]---------------------
# Error: 0.3145534090894662
# -------------------[EPOCH 28/200]---------------------
# Error: 0.30391359934414575
# -------------------[EPOCH 29/200]---------------------
# Error: 0.2936126554900797
# -------------------[EPOCH 30/200]---------------------
# Error: 0.2837310708430195
# -------------------[EPOCH 31/200]---------------------
# Error: 0.27436420935147593
# -------------------[EPOCH 32/200]---------------------
# Error: 0.2655298323077297
# -------------------[EPOCH 33/200]---------------------
# Error: 0.2572856473063332
# -------------------[EPOCH 34/200]---------------------
# Error: 0.24965090841994939
# -------------------[EPOCH 35/200]---------------------
# Error: 0.24261003861091113
# -------------------[EPOCH 36/200]---------------------
# Error: 0.23609503013226968
# -------------------[EPOCH 37/200]---------------------
# Error: 0.23006466549621202
# -------------------[EPOCH 38/200]---------------------
# Error: 0.2244953067927911
# -------------------[EPOCH 39/200]---------------------
# Error: 0.21938395947633643
# -------------------[EPOCH 40/200]---------------------
# Error: 0.21468441133129262
# -------------------[EPOCH 41/200]---------------------
# Error: 0.2103599950212051
# -------------------[EPOCH 42/200]---------------------
# Error: 0.20637548632711536
# -------------------[EPOCH 43/200]---------------------
# Error: 0.20269542515440556
# -------------------[EPOCH 44/200]---------------------
# Error: 0.1992894693991725
# -------------------[EPOCH 45/200]---------------------
# Error: 0.19614849544398338
# -------------------[EPOCH 46/200]---------------------
# Error: 0.19324367055049219
# -------------------[EPOCH 47/200]---------------------
# Error: 0.19055110948874837
# -------------------[EPOCH 48/200]---------------------
# Error: 0.18805142395248362
# -------------------[EPOCH 49/200]---------------------
# Error: 0.18572615740724677
# -------------------[EPOCH 50/200]---------------------
# Error: 0.18355932284944432
# -------------------[EPOCH 51/200]---------------------
# Error: 0.18153616519401364
# -------------------[EPOCH 52/200]---------------------
# Error: 0.17964401808416403
# -------------------[EPOCH 53/200]---------------------
# Error: 0.17787142689764482
# -------------------[EPOCH 54/200]---------------------
# Error: 0.1762078259336877
# -------------------[EPOCH 55/200]---------------------
# Error: 0.17464367924492624
# -------------------[EPOCH 56/200]---------------------
# Error: 0.1731704738414179
# -------------------[EPOCH 57/200]---------------------
# Error: 0.17178087006107576
# -------------------[EPOCH 58/200]---------------------
# Error: 0.17046872172893096
# -------------------[EPOCH 59/200]---------------------
# Error: 0.16922799290364213
# -------------------[EPOCH 60/200]---------------------
# Error: 0.16805349336734435
# -------------------[EPOCH 61/200]---------------------
# Error: 0.16693982078102707
# -------------------[EPOCH 62/200]---------------------
# Error: 0.1658821753918375
# -------------------[EPOCH 63/200]---------------------
# Error: 0.16487632247740053
# -------------------[EPOCH 64/200]---------------------
# Error: 0.16391843522588914
# -------------------[EPOCH 65/200]---------------------
# Error: 0.16300505917119712
# -------------------[EPOCH 66/200]---------------------
# Error: 0.16213307565791962
# -------------------[EPOCH 67/200]---------------------
# Error: 0.1612996594985612
# -------------------[EPOCH 68/200]---------------------
# Error: 0.16050224491185597
# -------------------[EPOCH 69/200]---------------------
# Error: 0.15973855273112444
# -------------------[EPOCH 70/200]---------------------
# Error: 0.15900648359635655
# -------------------[EPOCH 71/200]---------------------
# Error: 0.15830408091594078
# -------------------[EPOCH 72/200]---------------------
# Error: 0.15762916111703265
# -------------------[EPOCH 73/200]---------------------
# Error: 0.15697851161678847
# -------------------[EPOCH 74/200]---------------------
# Error: 0.15635261843912465
# -------------------[EPOCH 75/200]---------------------
# Error: 0.1557506291704143
# -------------------[EPOCH 76/200]---------------------
# Error: 0.15517146636583026
# -------------------[EPOCH 77/200]---------------------
# Error: 0.15461394867866263
# -------------------[EPOCH 78/200]---------------------
# Error: 0.15407703400930958
# -------------------[EPOCH 79/200]---------------------
# Error: 0.15355969969716343
# -------------------[EPOCH 80/200]---------------------
# Error: 0.15306100303893896
# -------------------[EPOCH 81/200]---------------------
# Error: 0.1525808107023974
# -------------------[EPOCH 82/200]---------------------
# Error: 0.15211813836120533
# -------------------[EPOCH 83/200]---------------------
# Error: 0.15167199672596043
# -------------------[EPOCH 84/200]---------------------
# Error: 0.15124150534658887
# -------------------[EPOCH 85/200]---------------------
# Error: 0.15082588352346923
# -------------------[EPOCH 86/200]---------------------
# Error: 0.15042442300138073
# -------------------[EPOCH 87/200]---------------------
# Error: 0.150036471759557
# -------------------[EPOCH 88/200]---------------------
# Error: 0.1496614239336215
# -------------------[EPOCH 89/200]---------------------
# Error: 0.14929871317369436
# -------------------[EPOCH 90/200]---------------------
# Error: 0.1489478079689584
# -------------------[EPOCH 91/200]---------------------
# Error: 0.14860820813282577
# -------------------[EPOCH 92/200]---------------------
# Error: 0.1482794420030138
# -------------------[EPOCH 93/200]---------------------
# Error: 0.14796106410672977
# -------------------[EPOCH 94/200]---------------------
# Error: 0.14765265314808518
# -------------------[EPOCH 95/200]---------------------
# Error: 0.14735371491761323
# -------------------[EPOCH 96/200]---------------------
# Error: 0.14706360367432583
# -------------------[EPOCH 97/200]---------------------
# Error: 0.14678201516541764
# -------------------[EPOCH 98/200]---------------------
# Error: 0.14650866378850766
# -------------------[EPOCH 99/200]---------------------
# Error: 0.14624326828745396
# -------------------[EPOCH 100/200]---------------------
# Error: 0.1459855548522042
# -------------------[EPOCH 101/200]---------------------
# Error: 0.1457352585767408
# -------------------[EPOCH 102/200]---------------------
# Error: 0.1454921240359282
# -------------------[EPOCH 103/200]---------------------
# Error: 0.14525590539343025
# -------------------[EPOCH 104/200]---------------------
# Error: 0.1450263689442782
# -------------------[EPOCH 105/200]---------------------
# Error: 0.1448033072462898
# -------------------[EPOCH 106/200]---------------------
# Error: 0.14458650959758998
# -------------------[EPOCH 107/200]---------------------
# Error: 0.14437576443080608
# -------------------[EPOCH 108/200]---------------------
# Error: 0.1441708684394067
# -------------------[EPOCH 109/200]---------------------
# Error: 0.1439716262344661
# -------------------[EPOCH 110/200]---------------------
# Error: 0.14377785375288185
# -------------------[EPOCH 111/200]---------------------
# Error: 0.1435894230722876
# -------------------[EPOCH 112/200]---------------------
# Error: 0.14340615601981133
# -------------------[EPOCH 113/200]---------------------
# Error: 0.1432278773631337
# -------------------[EPOCH 114/200]---------------------
# Error: 0.14305442034599702
# -------------------[EPOCH 115/200]---------------------
# Error: 0.14288562564213386
# -------------------[EPOCH 116/200]---------------------
# Error: 0.14272134064173916
# -------------------[EPOCH 117/200]---------------------
# Error: 0.14256141892872431
# -------------------[EPOCH 118/200]---------------------
# Error: 0.14240571987088474
# -------------------[EPOCH 119/200]---------------------
# Error: 0.14225410827987015
# -------------------[EPOCH 120/200]---------------------
# Error: 0.1421064541168023
# -------------------[EPOCH 121/200]---------------------
# Error: 0.1419626322297435
# -------------------[EPOCH 122/200]---------------------
# Error: 0.1418225221149198
# -------------------[EPOCH 123/200]---------------------
# Error: 0.14168600769675868
# -------------------[EPOCH 124/200]---------------------
# Error: 0.1415529771235726
# -------------------[EPOCH 125/200]---------------------
# Error: 0.1414233225767284
# -------------------[EPOCH 126/200]---------------------
# Error: 0.14129694009174
# -------------------[EPOCH 127/200]---------------------
# Error: 0.14117372939008085
# -------------------[EPOCH 128/200]---------------------
# Error: 0.14105359372074294
# -------------------[EPOCH 129/200]---------------------
# Error: 0.1409364397107288
# -------------------[EPOCH 130/200]---------------------
# Error: 0.14082217722376925
# -------------------[EPOCH 131/200]---------------------
# Error: 0.1407107192266488
# -------------------[EPOCH 132/200]---------------------
# Error: 0.14060198166258706
# -------------------[EPOCH 133/200]---------------------
# Error: 0.14049588333117782
# -------------------[EPOCH 134/200]---------------------
# Error: 0.14039234577443666
# -------------------[EPOCH 135/200]---------------------
# Error: 0.14029129316854974
# -------------------[EPOCH 136/200]---------------------
# Error: 0.14019265222095134
# -------------------[EPOCH 137/200]---------------------
# Error: 0.1400963520723851
# -------------------[EPOCH 138/200]---------------------
# Error: 0.14000232187816994
# -------------------[EPOCH 139/200]---------------------
# Error: 0.13991050067595603
# -------------------[EPOCH 140/200]---------------------
# Error: 0.13982082686146985
# -------------------[EPOCH 141/200]---------------------
# Error: 0.13973323974583277
# -------------------[EPOCH 142/200]---------------------
# Error: 0.13964767990965568
# -------------------[EPOCH 143/200]---------------------
# Error: 0.13956408948073257
# -------------------[EPOCH 144/200]---------------------
# Error: 0.1394824122521486
# -------------------[EPOCH 145/200]---------------------
# Error: 0.13940259371541502
# -------------------[EPOCH 146/200]---------------------
# Error: 0.13932458104900056
# -------------------[EPOCH 147/200]---------------------
# Error: 0.1392483230840544
# -------------------[EPOCH 148/200]---------------------
# Error: 0.13917377025905922
# -------------------[EPOCH 149/200]---------------------
# Error: 0.13910087432558285
# -------------------[EPOCH 150/200]---------------------
# Error: 0.13902957914930578
# -------------------[EPOCH 151/200]---------------------
# Error: 0.13895984128335295
# -------------------[EPOCH 152/200]---------------------
# Error: 0.13889161807840592
# -------------------[EPOCH 153/200]---------------------
# Error: 0.13882486766053934
# -------------------[EPOCH 154/200]---------------------
# Error: 0.1387595491873248
# -------------------[EPOCH 155/200]---------------------
# Error: 0.138695622961588
# -------------------[EPOCH 156/200]---------------------
# Error: 0.13863305046947944
# -------------------[EPOCH 157/200]---------------------
# Error: 0.1385717943788919
# -------------------[EPOCH 158/200]---------------------
# Error: 0.1385118185176497
# -------------------[EPOCH 159/200]---------------------
# Error: 0.1384530878418919
# -------------------[EPOCH 160/200]---------------------
# Error: 0.13839556840020972
# -------------------[EPOCH 161/200]---------------------
# Error: 0.1383392272964616
# -------------------[EPOCH 162/200]---------------------
# Error: 0.1382840326932584
# -------------------[EPOCH 163/200]---------------------
# Error: 0.13822995609882635
# -------------------[EPOCH 164/200]---------------------
# Error: 0.1381769676745951
# -------------------[EPOCH 165/200]---------------------
# Error: 0.13812503910345375
# -------------------[EPOCH 166/200]---------------------
# Error: 0.1380741425254318
# -------------------[EPOCH 167/200]---------------------
# Error: 0.1380242599365029
# -------------------[EPOCH 168/200]---------------------
# Error: 0.13797537525376136
# -------------------[EPOCH 169/200]---------------------
# Error: 0.13792746372611386
# -------------------[EPOCH 170/200]---------------------
# Error: 0.1378804992603163
# -------------------[EPOCH 171/200]---------------------
# Error: 0.13783445577914896
# -------------------[EPOCH 172/200]---------------------
# Error: 0.13778930768347333
# -------------------[EPOCH 173/200]---------------------
# Error: 0.13774503007294578
# -------------------[EPOCH 174/200]---------------------
# Error: 0.13770159883874813
# -------------------[EPOCH 175/200]---------------------
# Error: 0.13765899068950538
# -------------------[EPOCH 176/200]---------------------
# Error: 0.13761718314325952
# -------------------[EPOCH 177/200]---------------------
# Error: 0.13757615450306393
# -------------------[EPOCH 178/200]---------------------
# Error: 0.13753588382548323
# -------------------[EPOCH 179/200]---------------------
# Error: 0.13749635088682394
# -------------------[EPOCH 180/200]---------------------
# Error: 0.13745753614953166
# -------------------[EPOCH 181/200]---------------------
# Error: 0.13741942072991387
# -------------------[EPOCH 182/200]---------------------
# Error: 0.137381986367677
# -------------------[EPOCH 183/200]---------------------
# Error: 0.1373452153974219
# -------------------[EPOCH 184/200]---------------------
# Error: 0.13730909072206926
# -------------------[EPOCH 185/200]---------------------
# Error: 0.1372735957881064
# -------------------[EPOCH 186/200]---------------------
# Error: 0.13723871456251546
# -------------------[EPOCH 187/200]---------------------
# Error: 0.13720443151123843
# -------------------[EPOCH 188/200]---------------------
# Error: 0.13717073157903523
# -------------------[EPOCH 189/200]---------------------
# Error: 0.137137600170605
# -------------------[EPOCH 190/200]---------------------
# Error: 0.13710502313285314
# -------------------[EPOCH 191/200]---------------------
# Error: 0.13707298673819404
# -------------------[EPOCH 192/200]---------------------
# Error: 0.1370414776688005
# -------------------[EPOCH 193/200]---------------------
# Error: 0.1370104830017093
# -------------------[EPOCH 194/200]---------------------
# Error: 0.13697999019471407
# -------------------[EPOCH 195/200]---------------------
# Error: 0.1369499870729792
# -------------------[EPOCH 196/200]---------------------
# Error: 0.13692046181630946
# -------------------[EPOCH 197/200]---------------------
# Error: 0.13689140307810582
# -------------------[EPOCH 198/200]---------------------
# Error: 0.13686280115588298
# -------------------[EPOCH 199/200]---------------------
# Error: 0.13683464555659788
# -------------------[EPOCH 200/200]---------------------
# Error: 0.13680692568315184
# {'mse': np.float64(0.20312876873949598),
#  'mae': np.float64(0.3311149121775172),
#  'r2': np.float64(0.6720977328785933)}

# %%
model = GradientBoostedRegressionTree()
model.compile(n_estimators=10, learning_rate=0.1, max_depth=3, impurity_type="huber")

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

evaluation(y_pred, y_test)
# Out:
# -------------------[Iteration 0/10]---------------------
# Error : 0.3844905493645985
# -------------------[Iteration 1/10]---------------------
# Error : 0.35076804382331167
# -------------------[Iteration 2/10]---------------------
# Error : 0.3202994307140073
# -------------------[Iteration 3/10]---------------------
# Error : 0.29244992452779683
# -------------------[Iteration 4/10]---------------------
# Error : 0.2672993149312308
# -------------------[Iteration 5/10]---------------------
# Error : 0.2451150494289032
# -------------------[Iteration 6/10]---------------------
# Error : 0.22536536622580386
# -------------------[Iteration 7/10]---------------------
# Error : 0.20778695485764595
# -------------------[Iteration 8/10]---------------------
# Error : 0.19066823600004298
# -------------------[Iteration 9/10]---------------------
# Error : 0.17537899847913607
# {'mse': np.float64(0.24711754974615802),
#  'mae': np.float64(0.3367737861228029),
#  'r2': np.float64(0.6010884853480787)}

# %%
model = NearestNeighborFactory.create("regressor")
model.compile(k=4, metrics="manhattan")

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

evaluation(y_pred, y_test)
# Out:
# {'mse': np.float64(0.16742313521004726),
#  'mae': np.float64(0.2712400665218839),
#  'r2': np.float64(0.7297358422215753)}

# %%
model = IdentificationTreeFactory.create("regressor")
model.compile(max_depth=100, impurity_type="mse")

model.fit(x_train, y_train)
y_pred = model.predict(x_test)

evaluation(y_pred, y_test)
# Out:
# {'mse': np.float64(0.2796907923247256),
#  'mae': np.float64(0.3521212507955221),
#  'r2': np.float64(0.5485068635754111)}
